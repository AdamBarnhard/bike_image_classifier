# %%
# Load the "autoreload" extension. Prior to executing code, modules are reloaded. 
# There's no need to restart jupyter notebook if you modify code in the `src` directory.
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from src.data import make_dataset
import pandas as pd
import requests
import urllib
import ast
from random import randint
from time import sleep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bicycle_blue_book_search = 'https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId={year}&page={page}'

# %%
def extract_bbb_data(year, start_page, end_page, url_string, existing_df = None):
    # create dataframe to accumulate
    if existing_df:
        df = existing_df.copy()
    else:
        df = pd.DataFrame()
    
    # loop through pages
    for page_num in range(start_page,end_page+1):
        
        # create specific URL
        url_formatted = url_string.format(year=year, page=page_num)
        
        # pull data from the URL
        url_dict_string = urllib.request.urlopen(test_url).read().decode("UTF-8")
        url_dict = ast.literal_eval(url_dict_string)
        url_df = pd.DataFrame.from_dict(url_dict['data'])
        df = df.append(url_df)
        sleep(randint(1,7))
        print('Page ')
    
    return df.reset_index(drop=True)

# %%
extracted_bbb_2018 = extract_bbb_data(2018, 1, 20, bicycle_blue_book_search)

# %%
extracted_bbb_2018
# Out:
#      bicycleId                                        description  \
# 0      3079834   If you enjoy long days in the saddle and comi...
# 1      3079835   If you enjoy long days in the saddle and comi...
# 2      3079836   Scott's Addict CX 20 Disc is here, and the wo...
# 3      3079837   If you're one of the growing numbers of cycli...
# 4      3079838   If you're one of the growing numbers of cycli...
# ..         ...                                                ...
# 395    3079849   Get out and have some fun aboard Scott's Aspe...
# 396    3079850   Get out and have some fun aboard Scott's Aspe...
# 397    3079851   Get out there and hit up the trails on Scott&...
# 398    3079852   Experience big wheels and big fun on Scott's ...
# 399    3079853   Big fun awaits on Scott's Aspect 950. The lig...
#
#                                  name  brandId brandName  modelId  \
# 0                2018 Scott Addict 30      737     Scott    80123
# 1           2018 Scott Addict 30 Disc      737     Scott    89904
# 2        2018 Scott Addict CX 20 Disc      737     Scott    89905
# 3    2018 Scott Addict Gravel 10 Disc      737     Scott    89906
# 4    2018 Scott Addict Gravel 20 Disc      737     Scott    89907
# ..                                ...      ...       ...      ...
# 395             2018 Scott Aspect 770      737     Scott    89910
# 396             2018 Scott Aspect 780      737     Scott    89911
# 397             2018 Scott Aspect 930      737     Scott    78107
# 398             2018 Scott Aspect 940      737     Scott    76649
# 399             2018 Scott Aspect 950      737     Scott    76650
#
#                  modelName  yearId yearName  typeId    typeName  sizeId  \
# 0                Addict 30    2018     2018       1        Road       1
# 1           Addict 30 Disc    2018     2018       1        Road      20
# 2        Addict CX 20 Disc    2018     2018       3  Cyclocross      20
# 3    Addict Gravel 10 Disc    2018     2018       1        Road      42
# 4    Addict Gravel 20 Disc    2018     2018       1        Road      39
# ..                     ...     ...      ...     ...         ...     ...
# 395             Aspect 770    2018     2018       5    Mountain      33
# 396             Aspect 780    2018     2018       5    Mountain      11
# 397             Aspect 930    2018     2018       5    Mountain      16
# 398             Aspect 940    2018     2018       5    Mountain       3
# 399             Aspect 950    2018     2018       5    Mountain      26
#
#     sizeName  brakeTypeId brakeTypeName  \
# 0         XS            3       Caliper
# 1      59 cm            3       Caliper
# 2      59 cm            3       Caliper
# 3        23"            6    Cantilever
# 4      21.5"            6    Cantilever
# ..       ...          ...           ...
# 395      18"            6    Cantilever
# 396    50 cm            1          None
# 397    55 cm            6    Cantilever
# 398        M            6    Cantilever
# 399      13"            4      V-Brakes
#
#                                           imageDefault  \
# 0    https://www.sefiles.net/images/library/zoom/sc...
# 1    https://www.sefiles.net/images/library/zoom/sc...
# 2    https://www.sefiles.net/images/library/zoom/sc...
# 3    https://www.sefiles.net/images/library/zoom/sc...
# 4    https://www.sefiles.net/images/library/zoom/sc...
# ..                                                 ...
# 395  https://www.sefiles.net/images/library/zoom/sc...
# 396  https://www.sefiles.net/images/library/zoom/sc...
# 397  https://www.sefiles.net/images/library/zoom/sc...
# 398  https://www.sefiles.net/images/library/zoom/sc...
# 399  https://www.sefiles.net/images/library/zoom/sc...
#
#                                             yearModels
# 0    [{'id': 2015, 'name': '2015'}, {'id': 2019, 'n...
# 1    [{'id': 2017, 'name': '2017'}, {'id': 2019, 'n...
# 2                       [{'id': 2017, 'name': '2017'}]
# 3                       [{'id': 2017, 'name': '2017'}]
# 4                       [{'id': 2017, 'name': '2017'}]
# ..                                                 ...
# 395  [{'id': 2017, 'name': '2017'}, {'id': 2019, 'n...
# 396  [{'id': 2017, 'name': '2017'}, {'id': 2019, 'n...
# 397  [{'id': 2014, 'name': '2014'}, {'id': 2015, 'n...
# 398  [{'id': 2013, 'name': '2013'}, {'id': 2014, 'n...
# 399  [{'id': 2013, 'name': '2013'}, {'id': 2014, 'n...
#
# [400 rows x 17 columns]
