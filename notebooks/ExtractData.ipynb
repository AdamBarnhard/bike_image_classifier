# %%
# Load the "autoreload" extension. Prior to executing code, modules are reloaded. 
# There's no need to restart jupyter notebook if you modify code in the `src` directory.
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from src.data import make_dataset
import pandas as pd
import requests
import urllib
import ast
from random import randint
from time import sleep
import pickle
import urllib.request
import urllib.error
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bicycle_blue_book_search = 'https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId={year}&page={page}'

# %%
def extract_bbb_data(year, start_page, end_page, url_string, existing_df = None):
    # create dataframe to accumulate
    if existing_df:
        df = existing_df.copy()
    else:
        df = pd.DataFrame()
    
    # loop through pages
    for page_num in range(start_page,end_page+1):
        
        # create specific URL
        url_formatted = url_string.format(year=year, page=page_num)
        
        # pull data from the URL
        print(url_formatted)
        url_dict_string = urllib.request.urlopen(url_formatted).read().decode("UTF-8")
        url_dict = ast.literal_eval(url_dict_string)
        url_df = pd.DataFrame.from_dict(url_dict['data'])
        df = df.append(url_df)
        print('Page '+str(page_num))
    
    
    return df.reset_index(drop=True)

# %%
extracted_bbb_2018 = extract_bbb_data(2018, 1, 40, bicycle_blue_book_search)
# Out:
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=1
# Page 1
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=2
# Page 2
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=3
# Page 3
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=4
# Page 4
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=5
# Page 5
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=6
# Page 6
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=7
# Page 7
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=8
# Page 8
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=9
# Page 9
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=10
# Page 10
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=11
# Page 11
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=12
# Page 12
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=13
# Page 13
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=14
# Page 14
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=15
# Page 15
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=16
# Page 16
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=17
# Page 17
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=18
# Page 18
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=19
# Page 19
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=20
# Page 20
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=21
# Page 21
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=22
# Page 22
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=23
# Page 23
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=24
# Page 24
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=25
# Page 25
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=26
# Page 26
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=27
# Page 27
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=28
# Page 28
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=29
# Page 29
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=30
# Page 30
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=31
# Page 31
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=32
# Page 32
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=33
# Page 33
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=34
# Page 34
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=35
# Page 35
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=36
# Page 36
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=37
# Page 37
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=38
# Page 38
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=39
# Page 39
# https://api.bicyclebluebook.com/core/api/bicycles/brand/year/model?yearId=2018&page=40
# Page 40

# %%
extracted_bbb_2018
# Out:
#      bicycleId                                        description  \
# 0      3071340   If your cross bike functions asan everyday mo...
# 1      3071347   Disc brakes, one gear, and tons of fun: the N...
# 2      3071350   Combine two parts versatility, one part bike-...
# 3      3071535   When you&#8217;re on the Jekyll 4 from Cannon...
# 4      3071536   Cannondale&#8217;s Jekyll Carbon 1 gets you d...
# ..         ...                                                ...
# 795    3077514   Cannondale's Scalpel-Si Carbon Women's 2 asce...
# 796    3077515   Cannondale's Scalpel-Si Team cuts straight to...
# 797    3077516   The lightest, best climbing, best descending,...
# 798    3077517   Confident handling, and grippy, floaty 27+ ti...
# 799    3077518   Confident handling, and grippy, floaty 27+ ti...
#
#                                             name  brandId   brandName  \
# 0                   2018 All-City Macho Man Disc     1067    All-City
# 1                  2018 All-City Nature Boy Disc     1067    All-City
# 2                 2018 All-City Space Horse Disc     1067    All-City
# 3                       2018 Cannondale Jekyll 4      672  Cannondale
# 4                2018 Cannondale Jekyll Carbon 1      672  Cannondale
# ..                                           ...      ...         ...
# 795  2018 Cannondale Scalpel-Si Carbon 2 Women's      672  Cannondale
# 796              2018 Cannondale Scalpel-Si Team      672  Cannondale
# 797         2018 Cannondale Scalpel-Si 1 Women's      672  Cannondale
# 798                    2018 Cannondale Scarlet 1      672  Cannondale
# 799                    2018 Cannondale Scarlet 2      672  Cannondale
#
#      modelId                    modelName  yearId yearName  typeId  typeName  \
# 0      80624               Macho Man Disc    2018     2018       6    Hybrid
# 1      80632              Nature Boy Disc    2018     2018       6    Hybrid
# 2      88744             Space Horse Disc    2018     2018       6    Hybrid
# 3      63495                     Jekyll 4    2018     2018       5  Mountain
# 4      63497              Jekyll Carbon 1    2018     2018       5  Mountain
# ..       ...                          ...     ...      ...     ...       ...
# 795    86632  Scalpel-Si Carbon 2 Women's    2018     2018       5  Mountain
# 796    92120              Scalpel-Si Team    2018     2018       5  Mountain
# 797    92121         Scalpel-Si 1 Women's    2018     2018       5  Mountain
# 798    70545                    Scarlet 1    2018     2018       5  Mountain
# 799    70542                    Scarlet 2    2018     2018       5  Mountain
#
#      sizeId sizeName  brakeTypeId brakeTypeName  \
# 0        47      M/L            6    Cantilever
# 1         5       XL            7          Drum
# 2        27    14.5"            4      V-Brakes
# 3        42      23"            2          Disc
# 4         3        M            2          Disc
# ..      ...      ...          ...           ...
# 795      17    56 cm            2          Disc
# 796      11    50 cm            3       Caliper
# 797      43    23.5"            4      V-Brakes
# 798      49    104cm            3       Caliper
# 799       8    47 cm            1          None
#
#                                           imageDefault  \
# 0    https://www.sefiles.net/images/library/zoom/al...
# 1    https://www.sefiles.net/images/library/large/a...
# 2    https://www.sefiles.net/images/library/zoom/al...
# 3    https://www.sefiles.net/images/library/zoom/ca...
# 4    https://www.sefiles.net/images/library/zoom/ca...
# ..                                                 ...
# 795  https://www.sefiles.net/images/library/zoom/ca...
# 796  https://www.sefiles.net/images/library/zoom/ca...
# 797  https://www.sefiles.net/images/library/zoom/ca...
# 798  https://www.sefiles.net/images/library/zoom/ca...
# 799  https://www.sefiles.net/images/library/zoom/ca...
#
#                                             yearModels
# 0    [{'id': 2015, 'name': '2015'}, {'id': 2017, 'n...
# 1                       [{'id': 2015, 'name': '2015'}]
# 2    [{'id': 2017, 'name': '2017'}, {'id': 2019, 'n...
# 3    [{'id': 2011, 'name': '2011'}, {'id': 2012, 'n...
# 4    [{'id': 2011, 'name': '2011'}, {'id': 2012, 'n...
# ..                                                 ...
# 795                     [{'id': 2017, 'name': '2017'}]
# 796                                                 []
# 797                     [{'id': 2019, 'name': '2019'}]
# 798  [{'id': 2011, 'name': '2011'}, {'id': 2013, 'n...
# 799  [{'id': 2011, 'name': '2011'}, {'id': 2012, 'n...
#
# [800 rows x 17 columns]

# %%
with open('../data/raw/extracted_bbb_2018.pkl', 'wb') as f:
    pickle.dump(extracted_bbb_2018, f)

# %%
print(list(extracted_bbb_2018.typeName.unique()))

def bike_type_converter(type):
    if type in ['Hybrid', 'Mountain', 'Road', 'Cyclocross', 'Kids']:
        new_type = type
    else:
        new_type = 'Other'
    return(new_type)

converted_type_set = set()
for bike_type in list(extracted_bbb_2018.typeName.unique()):
    converted_type_set.add(bike_type_converter(bike_type))
    
for bike_type_directory in list(converted_type_set):
    path = '../data/raw/{}'
    os.mkdir(path.format(bike_type_directory))
# Out:
# ['Hybrid', 'Mountain', 'Other', 'Road', 'Cyclocross', 'Kids', 'BMX', 'Cruiser']

# %%
iterate_df = extracted_bbb_2018[['bicycleId','typeName','imageDefault']].iloc[482:800]

for i, row in enumerate(iterate_df.itertuples()):
    if pd.isna(row.imageDefault):
        print(i, 'Skipping')
        continue
    path = '../data/raw/{}/{}.png'
    adjusted_type=bike_type_converter(row.typeName)
    structured_path = path.format(adjusted_type, row.bicycleId)
    try:
        urllib.request.urlretrieve(row.imageDefault, structured_path)
    except urllib.error.HTTPError:
        print(i, 'Access Denied')
    print(i, structured_path)
# Out:
# 0 Skipping
# 1 Skipping
# 2 Skipping
# 3 Skipping
# 4 Skipping
# 5 Skipping
# 6 Skipping
# 7 Skipping
# 8 Skipping
# 9 Skipping
# 10 ../data/raw/Mountain/3076373.png
# 11 ../data/raw/Road/3076444.png
# 12 Skipping
# 13 ../data/raw/Road/3076526.png
# 14 Skipping
# 15 Skipping
# 16 ../data/raw/Mountain/3076853.png
# 17 ../data/raw/Mountain/3076876.png
# 18 ../data/raw/Mountain/3076939.png
# 19 ../data/raw/Road/3076964.png
# 20 ../data/raw/Mountain/3076988.png
# 21 ../data/raw/Mountain/3077007.png
# 22 Skipping
# 23 ../data/raw/Hybrid/3077164.png
# 24 ../data/raw/Mountain/3077167.png
# 25 ../data/raw/Road/3077169.png
# 26 ../data/raw/Mountain/3077171.png
# 27 ../data/raw/Cyclocross/3077173.png
# 28 ../data/raw/Cyclocross/3077174.png
# 29 ../data/raw/Hybrid/3077176.png
# 30 ../data/raw/Road/3077181.png
# 31 ../data/raw/Road/3077183.png
# 32 ../data/raw/Hybrid/3077184.png
# 33 ../data/raw/Hybrid/3077185.png
# 34 ../data/raw/Hybrid/3077189.png
# 35 ../data/raw/Road/3077196.png
# 36 ../data/raw/Road/3077197.png
# 37 ../data/raw/Road/3077198.png
# 38 ../data/raw/Hybrid/3077199.png
# 39 Access Denied
# 39 ../data/raw/Hybrid/3077200.png
# 40 ../data/raw/Hybrid/3077201.png
# 41 ../data/raw/Hybrid/3077202.png
# 42 ../data/raw/Hybrid/3077203.png
# 43 ../data/raw/Hybrid/3077204.png
# 44 ../data/raw/Hybrid/3077205.png
# 45 ../data/raw/Kids/3077206.png
# 46 ../data/raw/Kids/3077207.png
# 47 ../data/raw/Kids/3077208.png
